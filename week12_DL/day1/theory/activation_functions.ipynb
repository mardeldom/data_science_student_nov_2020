# %% [markdown]
# ### ReLu

# %%
def ReLU(x):
    return (abs(x) + x) / 2

# %%
ReLU(55)
# Out:
# 55.0

# %% [markdown]
# ### Sigmoid

# %%
import math

def sigmoid(x):
  return 1 / (1 + math.exp(-x))

# %% [markdown]
# ### Hyperbolic tangent

# %%
import tensorflow as tf 
# tf.keras.activations.tanh()

# %% [markdown]
# ## TESTING

# %%
import numpy as np
import matplotlib.pylab as plt

_ = np.arange(10)
x_ = np.random.random(10) - 5
x_
# Out:
# array([-4.57808119, -4.32893679, -4.0266027 , -4.00069109, -4.2741212 ,
#        -4.61774568, -4.53713498, -4.15833183, -4.96335787, -4.25881214])

# %%
plt.plot(_, x_)

# %%
plt.plot(_, ReLU(x_))

# %%
y_sigmoid_ = [sigmoid(x) for x in x_]

plt.scatter(x_, y_sigmoid_)

# %%
tf.keras.activations.tanh(1.)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.7615942>
